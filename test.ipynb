# %%
import pandas as pd
from datetime import datetime 

START_DATE = '2024-01-01'
END_DATE = '2025-02-28'

end_date = pd.Timestamp(datetime.strptime(END_DATE, '%Y-%m-%d'))
start_date = pd.Timestamp(datetime.strptime(START_DATE, '%Y-%m-%d'))

inputs=[
    "01_raw.{}.foo_raw_df", 
    ]
outputs="02_intermediate.{}.foo_intermediate_df"

if isinstance(inputs, str):
    inputs = [inputs]
if isinstance(outputs, str):
    outputs = [outputs]

print(inputs)
# Out:
# ['01_raw.{}.foo_raw_df']

# %%
period = 'daily'

if period == 'latest':
    date_list = [end_date]

elif period == 'daily':
    date_list = pd.date_range(start=start_date, end=end_date, freq='D')

elif period == 'monthly':
    date_list = pd.date_range(start=start_date, end=end_date, freq='M')

elif period == 'quarterly':
    date_list = pd.date_range(start=start_date, end=end_date, freq='Q')

elif period == 'yearly':
    date_list = pd.date_range(start=start_date, end=end_date, freq='Y')
else:
    raise ValueError(f"Invalid period: {period}. Must be one of 'latest', 'daily', 'monthly', 'quarterly', 'yearly'")

# %%
date_list
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08',
#                '2024-01-09', '2024-01-10',
#                ...
#                '2025-02-19', '2025-02-20', '2025-02-21', '2025-02-22',
#                '2025-02-23', '2025-02-24', '2025-02-25', '2025-02-26',
#                '2025-02-27', '2025-02-28'],
#               dtype='datetime64[ns]', length=425, freq='D')

# %%
from dateutil.relativedelta import relativedelta
import datetime as dt

for date in date_list:
    formatted_date = date.strftime('%Y-%m-%d')
    # print(formatted_date)
    # print(type(formatted_date))

    d = dt.datetime.strptime(formatted_date, "%Y-%m-%d")
    # print(d)
    # print(type(d))

    date_range = []
    
    for i in range(1):
        if period == 'latest':
            # Just use the reference date
            date_str = (d - relativedelta(days=i)).strftime("%Y-%m-%d")
            
        elif period == 'daily':
            # Look back by days
            date_str = (d - relativedelta(days=i)).strftime("%Y-%m-%d")
            
        elif period == 'monthly':
            # Look back by months with wildcard for days
            date_str = (d - relativedelta(months=i)).strftime("%Y-%m-??")
            
        elif period == 'quarterly':
            # Look back by quarters with wildcard for month and day
            quarter_date = d - relativedelta(months=i*3)
            quarter = ((quarter_date.month - 1) // 3) + 1
            date_str = f"{quarter_date.year}-Q{quarter}"
            
        elif period == 'yearly':
            # Look back by years with wildcard
            date_str = (d - relativedelta(years=i)).strftime("%Y-??-??")
            
        else:
            # Default to monthly if period is not recognized
            date_str = (d - relativedelta(months=i)).strftime("%Y-%m-??")
            
        date_range.append(date_str)
         
    pattern = "{" + ",".join(date_range) + "}"
    print(pattern)
    formatted_inputs =  [x.format(pattern) if "{" in x else x for x in inputs]
    formatted_inputs.append(f"params:{formatted_date}")
    print(formatted_inputs)
    formatted_outputs =  [x.format(formatted_date) if "{" in x else x for x in outputs]
    print(formatted_outputs)
# Out:
# {2024-01-01}
# ['01_raw.{2024-01-01}.foo_raw_df', 'params:2024-01-01']
# ['02_intermediate.2024-01-01.foo_intermediate_df']
# {2024-01-02}
# ['01_raw.{2024-01-02}.foo_raw_df', 'params:2024-01-02']
# ['02_intermediate.2024-01-02.foo_intermediate_df']
# {2024-01-03}
# ['01_raw.{2024-01-03}.foo_raw_df', 'params:2024-01-03']
# ['02_intermediate.2024-01-03.foo_intermediate_df']
# {2024-01-04}
# ['01_raw.{2024-01-04}.foo_raw_df', 'params:2024-01-04']
# ['02_intermediate.2024-01-04.foo_intermediate_df']
# {2024-01-05}
# ['01_raw.{2024-01-05}.foo_raw_df', 'params:2024-01-05']
# ['02_intermediate.2024-01-05.foo_intermediate_df']
# {2024-01-06}
# ['01_raw.{2024-01-06}.foo_raw_df', 'params:2024-01-06']
# ['02_intermediate.2024-01-06.foo_intermediate_df']
# {2024-01-07}
# ['01_raw.{2024-01-07}.foo_raw_df', 'params:2024-01-07']
# ['02_intermediate.2024-01-07.foo_intermediate_df']
# {2024-01-08}
# ['01_raw.{2024-01-08}.foo_raw_df', 'params:2024-01-08']
# ['02_intermediate.2024-01-08.foo_intermediate_df']
# {2024-01-09}
# ['01_raw.{2024-01-09}.foo_raw_df', 'params:2024-01-09']
# ['02_intermediate.2024-01-09.foo_intermediate_df']
# {2024-01-10}
# ['01_raw.{2024-01-10}.foo_raw_df', 'params:2024-01-10']
# ['02_intermediate.2024-01-10.foo_intermediate_df']
# {2024-01-11}
# ['01_raw.{2024-01-11}.foo_raw_df', 'params:2024-01-11']
# ['02_intermediate.2024-01-11.foo_intermediate_df']
# {2024-01-12}
# ['01_raw.{2024-01-12}.foo_raw_df', 'params:2024-01-12']
# ['02_intermediate.2024-01-12.foo_intermediate_df']
# {2024-01-13}
# ['01_raw.{2024-01-13}.foo_raw_df', 'params:2024-01-13']
# ['02_intermediate.2024-01-13.foo_intermediate_df']
# {2024-01-14}
# ['01_raw.{2024-01-14}.foo_raw_df', 'params:2024-01-14']
# ['02_intermediate.2024-01-14.foo_intermediate_df']
# {2024-01-15}
# ['01_raw.{2024-01-15}.foo_raw_df', 'params:2024-01-15']
# ['02_intermediate.2024-01-15.foo_intermediate_df']
# {2024-01-16}
# ['01_raw.{2024-01-16}.foo_raw_df', 'params:2024-01-16']
# ['02_intermediate.2024-01-16.foo_intermediate_df']
# {2024-01-17}
# ['01_raw.{2024-01-17}.foo_raw_df', 'params:2024-01-17']
# ['02_intermediate.2024-01-17.foo_intermediate_df']
# {2024-01-18}
# ['01_raw.{2024-01-18}.foo_raw_df', 'params:2024-01-18']
# ['02_intermediate.2024-01-18.foo_intermediate_df']
# {2024-01-19}
# ['01_raw.{2024-01-19}.foo_raw_df', 'params:2024-01-19']
# ['02_intermediate.2024-01-19.foo_intermediate_df']
# {2024-01-20}
# ['01_raw.{2024-01-20}.foo_raw_df', 'params:2024-01-20']
# ['02_intermediate.2024-01-20.foo_intermediate_df']
# {2024-01-21}
# ['01_raw.{2024-01-21}.foo_raw_df', 'params:2024-01-21']
# ['02_intermediate.2024-01-21.foo_intermediate_df']
# {2024-01-22}
# ['01_raw.{2024-01-22}.foo_raw_df', 'params:2024-01-22']
# ['02_intermediate.2024-01-22.foo_intermediate_df']
# {2024-01-23}
# ['01_raw.{2024-01-23}.foo_raw_df', 'params:2024-01-23']
# ['02_intermediate.2024-01-23.foo_intermediate_df']
# {2024-01-24}
# ['01_raw.{2024-01-24}.foo_raw_df', 'params:2024-01-24']
# ['02_intermediate.2024-01-24.foo_intermediate_df']
# {2024-01-25}
# ['01_raw.{2024-01-25}.foo_raw_df', 'params:2024-01-25']
# ['02_intermediate.2024-01-25.foo_intermediate_df']
# {2024-01-26}
# ['01_raw.{2024-01-26}.foo_raw_df', 'params:2024-01-26']
# ['02_intermediate.2024-01-26.foo_intermediate_df']
# {2024-01-27}
# ['01_raw.{2024-01-27}.foo_raw_df', 'params:2024-01-27']
# ['02_intermediate.2024-01-27.foo_intermediate_df']
# {2024-01-28}
# ['01_raw.{2024-01-28}.foo_raw_df', 'params:2024-01-28']
# ['02_intermediate.2024-01-28.foo_intermediate_df']
# {2024-01-29}
# ['01_raw.{2024-01-29}.foo_raw_df', 'params:2024-01-29']
# ['02_intermediate.2024-01-29.foo_intermediate_df']
# {2024-01-30}
# ['01_raw.{2024-01-30}.foo_raw_df', 'params:2024-01-30']
# ['02_intermediate.2024-01-30.foo_intermediate_df']
# {2024-01-31}
# ['01_raw.{2024-01-31}.foo_raw_df', 'params:2024-01-31']
# ['02_intermediate.2024-01-31.foo_intermediate_df']
# {2024-02-01}
# ['01_raw.{2024-02-01}.foo_raw_df', 'params:2024-02-01']
# ['02_intermediate.2024-02-01.foo_intermediate_df']
# {2024-02-02}
# ['01_raw.{2024-02-02}.foo_raw_df', 'params:2024-02-02']
# ['02_intermediate.2024-02-02.foo_intermediate_df']
# {2024-02-03}
# ['01_raw.{2024-02-03}.foo_raw_df', 'params:2024-02-03']
# ['02_intermediate.2024-02-03.foo_intermediate_df']
# {2024-02-04}
# ['01_raw.{2024-02-04}.foo_raw_df', 'params:2024-02-04']
# ['02_intermediate.2024-02-04.foo_intermediate_df']
# {2024-02-05}
# ['01_raw.{2024-02-05}.foo_raw_df', 'params:2024-02-05']
# ['02_intermediate.2024-02-05.foo_intermediate_df']
# {2024-02-06}
# ['01_raw.{2024-02-06}.foo_raw_df', 'params:2024-02-06']
# ['02_intermediate.2024-02-06.foo_intermediate_df']
# {2024-02-07}
# ['01_raw.{2024-02-07}.foo_raw_df', 'params:2024-02-07']
# ['02_intermediate.2024-02-07.foo_intermediate_df']
# {2024-02-08}
# ['01_raw.{2024-02-08}.foo_raw_df', 'params:2024-02-08']
# ['02_intermediate.2024-02-08.foo_intermediate_df']
# {2024-02-09}
# ['01_raw.{2024-02-09}.foo_raw_df', 'params:2024-02-09']
# ['02_intermediate.2024-02-09.foo_intermediate_df']
# {2024-02-10}
# ['01_raw.{2024-02-10}.foo_raw_df', 'params:2024-02-10']
# ['02_intermediate.2024-02-10.foo_intermediate_df']
# {2024-02-11}
# ['01_raw.{2024-02-11}.foo_raw_df', 'params:2024-02-11']
# ['02_intermediate.2024-02-11.foo_intermediate_df']
# {2024-02-12}
# ['01_raw.{2024-02-12}.foo_raw_df', 'params:2024-02-12']
# ['02_intermediate.2024-02-12.foo_intermediate_df']
# {2024-02-13}
# ['01_raw.{2024-02-13}.foo_raw_df', 'params:2024-02-13']
# ['02_intermediate.2024-02-13.foo_intermediate_df']
# {2024-02-14}
# ['01_raw.{2024-02-14}.foo_raw_df', 'params:2024-02-14']
# ['02_intermediate.2024-02-14.foo_intermediate_df']
# {2024-02-15}
# ['01_raw.{2024-02-15}.foo_raw_df', 'params:2024-02-15']
# ['02_intermediate.2024-02-15.foo_intermediate_df']
# {2024-02-16}
# ['01_raw.{2024-02-16}.foo_raw_df', 'params:2024-02-16']
# ['02_intermediate.2024-02-16.foo_intermediate_df']
# {2024-02-17}
# ['01_raw.{2024-02-17}.foo_raw_df', 'params:2024-02-17']
# ['02_intermediate.2024-02-17.foo_intermediate_df']
# {2024-02-18}
# ['01_raw.{2024-02-18}.foo_raw_df', 'params:2024-02-18']
# ['02_intermediate.2024-02-18.foo_intermediate_df']
# {2024-02-19}
# ['01_raw.{2024-02-19}.foo_raw_df', 'params:2024-02-19']
# ['02_intermediate.2024-02-19.foo_intermediate_df']
# {2024-02-20}
# ['01_raw.{2024-02-20}.foo_raw_df', 'params:2024-02-20']
# ['02_intermediate.2024-02-20.foo_intermediate_df']
# {2024-02-21}
# ['01_raw.{2024-02-21}.foo_raw_df', 'params:2024-02-21']
# ['02_intermediate.2024-02-21.foo_intermediate_df']
# {2024-02-22}
# ['01_raw.{2024-02-22}.foo_raw_df', 'params:2024-02-22']
# ['02_intermediate.2024-02-22.foo_intermediate_df']
# {2024-02-23}
# ['01_raw.{2024-02-23}.foo_raw_df', 'params:2024-02-23']
# ['02_intermediate.2024-02-23.foo_intermediate_df']
# {2024-02-24}
# ['01_raw.{2024-02-24}.foo_raw_df', 'params:2024-02-24']
# ['02_intermediate.2024-02-24.foo_intermediate_df']
# {2024-02-25}
# ['01_raw.{2024-02-25}.foo_raw_df', 'params:2024-02-25']
# ['02_intermediate.2024-02-25.foo_intermediate_df']
# {2024-02-26}
# ['01_raw.{2024-02-26}.foo_raw_df', 'params:2024-02-26']
# ['02_intermediate.2024-02-26.foo_intermediate_df']
# {2024-02-27}
# ['01_raw.{2024-02-27}.foo_raw_df', 'params:2024-02-27']
# ['02_intermediate.2024-02-27.foo_intermediate_df']
# {2024-02-28}
# ['01_raw.{2024-02-28}.foo_raw_df', 'params:2024-02-28']
# ['02_intermediate.2024-02-28.foo_intermediate_df']
# {2024-02-29}
# ['01_raw.{2024-02-29}.foo_raw_df', 'params:2024-02-29']
# ['02_intermediate.2024-02-29.foo_intermediate_df']
# {2024-03-01}
# ['01_raw.{2024-03-01}.foo_raw_df', 'params:2024-03-01']
# ['02_intermediate.2024-03-01.foo_intermediate_df']
# {2024-03-02}
# ['01_raw.{2024-03-02}.foo_raw_df', 'params:2024-03-02']
# ['02_intermediate.2024-03-02.foo_intermediate_df']
# {2024-03-03}
# ['01_raw.{2024-03-03}.foo_raw_df', 'params:2024-03-03']
# ['02_intermediate.2024-03-03.foo_intermediate_df']
# {2024-03-04}
# ['01_raw.{2024-03-04}.foo_raw_df', 'params:2024-03-04']
# ['02_intermediate.2024-03-04.foo_intermediate_df']
# {2024-03-05}
# ['01_raw.{2024-03-05}.foo_raw_df', 'params:2024-03-05']
# ['02_intermediate.2024-03-05.foo_intermediate_df']
# {2024-03-06}
# ['01_raw.{2024-03-06}.foo_raw_df', 'params:2024-03-06']
# ['02_intermediate.2024-03-06.foo_intermediate_df']
# {2024-03-07}
# ['01_raw.{2024-03-07}.foo_raw_df', 'params:2024-03-07']
# ['02_intermediate.2024-03-07.foo_intermediate_df']
# {2024-03-08}
# ['01_raw.{2024-03-08}.foo_raw_df', 'params:2024-03-08']
# ['02_intermediate.2024-03-08.foo_intermediate_df']
# {2024-03-09}
# ['01_raw.{2024-03-09}.foo_raw_df', 'params:2024-03-09']
# ['02_intermediate.2024-03-09.foo_intermediate_df']
# {2024-03-10}
# ['01_raw.{2024-03-10}.foo_raw_df', 'params:2024-03-10']
# ['02_intermediate.2024-03-10.foo_intermediate_df']
# {2024-03-11}
# ['01_raw.{2024-03-11}.foo_raw_df', 'params:2024-03-11']
# ['02_intermediate.2024-03-11.foo_intermediate_df']
# {2024-03-12}
# ['01_raw.{2024-03-12}.foo_raw_df', 'params:2024-03-12']
# ['02_intermediate.2024-03-12.foo_intermediate_df']
# {2024-03-13}
# ['01_raw.{2024-03-13}.foo_raw_df', 'params:2024-03-13']
# ['02_intermediate.2024-03-13.foo_intermediate_df']
# {2024-03-14}
# ['01_raw.{2024-03-14}.foo_raw_df', 'params:2024-03-14']
# ['02_intermediate.2024-03-14.foo_intermediate_df']
# {2024-03-15}
# ['01_raw.{2024-03-15}.foo_raw_df', 'params:2024-03-15']
# ['02_intermediate.2024-03-15.foo_intermediate_df']
# {2024-03-16}
# ['01_raw.{2024-03-16}.foo_raw_df', 'params:2024-03-16']
# ['02_intermediate.2024-03-16.foo_intermediate_df']
# {2024-03-17}
# ['01_raw.{2024-03-17}.foo_raw_df', 'params:2024-03-17']
# ['02_intermediate.2024-03-17.foo_intermediate_df']
# {2024-03-18}
# ['01_raw.{2024-03-18}.foo_raw_df', 'params:2024-03-18']
# ['02_intermediate.2024-03-18.foo_intermediate_df']
# {2024-03-19}
# ['01_raw.{2024-03-19}.foo_raw_df', 'params:2024-03-19']
# ['02_intermediate.2024-03-19.foo_intermediate_df']
# {2024-03-20}
# ['01_raw.{2024-03-20}.foo_raw_df', 'params:2024-03-20']
# ['02_intermediate.2024-03-20.foo_intermediate_df']
# {2024-03-21}
# ['01_raw.{2024-03-21}.foo_raw_df', 'params:2024-03-21']
# ['02_intermediate.2024-03-21.foo_intermediate_df']
# {2024-03-22}
# ['01_raw.{2024-03-22}.foo_raw_df', 'params:2024-03-22']
# ['02_intermediate.2024-03-22.foo_intermediate_df']
# {2024-03-23}
# ['01_raw.{2024-03-23}.foo_raw_df', 'params:2024-03-23']
# ['02_intermediate.2024-03-23.foo_intermediate_df']
# {2024-03-24}
# ['01_raw.{2024-03-24}.foo_raw_df', 'params:2024-03-24']
# ['02_intermediate.2024-03-24.foo_intermediate_df']
# {2024-03-25}
# ['01_raw.{2024-03-25}.foo_raw_df', 'params:2024-03-25']
# ['02_intermediate.2024-03-25.foo_intermediate_df']
# {2024-03-26}
# ['01_raw.{2024-03-26}.foo_raw_df', 'params:2024-03-26']
# ['02_intermediate.2024-03-26.foo_intermediate_df']
# {2024-03-27}
# ['01_raw.{2024-03-27}.foo_raw_df', 'params:2024-03-27']
# ['02_intermediate.2024-03-27.foo_intermediate_df']
# {2024-03-28}
# ['01_raw.{2024-03-28}.foo_raw_df', 'params:2024-03-28']
# ['02_intermediate.2024-03-28.foo_intermediate_df']
# {2024-03-29}
# ['01_raw.{2024-03-29}.foo_raw_df', 'params:2024-03-29']
# ['02_intermediate.2024-03-29.foo_intermediate_df']
# {2024-03-30}
# ['01_raw.{2024-03-30}.foo_raw_df', 'params:2024-03-30']
# ['02_intermediate.2024-03-30.foo_intermediate_df']
# {2024-03-31}
# ['01_raw.{2024-03-31}.foo_raw_df', 'params:2024-03-31']
# ['02_intermediate.2024-03-31.foo_intermediate_df']
# {2024-04-01}
# ['01_raw.{2024-04-01}.foo_raw_df', 'params:2024-04-01']
# ['02_intermediate.2024-04-01.foo_intermediate_df']
# {2024-04-02}
# ['01_raw.{2024-04-02}.foo_raw_df', 'params:2024-04-02']
# ['02_intermediate.2024-04-02.foo_intermediate_df']
# {2024-04-03}
# ['01_raw.{2024-04-03}.foo_raw_df', 'params:2024-04-03']
# ['02_intermediate.2024-04-03.foo_intermediate_df']
# {2024-04-04}
# ['01_raw.{2024-04-04}.foo_raw_df', 'params:2024-04-04']
# ['02_intermediate.2024-04-04.foo_intermediate_df']
# {2024-04-05}
# ['01_raw.{2024-04-05}.foo_raw_df', 'params:2024-04-05']
# ['02_intermediate.2024-04-05.foo_intermediate_df']
# {2024-04-06}
# ['01_raw.{2024-04-06}.foo_raw_df', 'params:2024-04-06']
# ['02_intermediate.2024-04-06.foo_intermediate_df']
# {2024-04-07}
# ['01_raw.{2024-04-07}.foo_raw_df', 'params:2024-04-07']
# ['02_intermediate.2024-04-07.foo_intermediate_df']
# {2024-04-08}
# ['01_raw.{2024-04-08}.foo_raw_df', 'params:2024-04-08']
# ['02_intermediate.2024-04-08.foo_intermediate_df']
# {2024-04-09}
# ['01_raw.{2024-04-09}.foo_raw_df', 'params:2024-04-09']
# ['02_intermediate.2024-04-09.foo_intermediate_df']
# {2024-04-10}
# ['01_raw.{2024-04-10}.foo_raw_df', 'params:2024-04-10']
# ['02_intermediate.2024-04-10.foo_intermediate_df']
# {2024-04-11}
# ['01_raw.{2024-04-11}.foo_raw_df', 'params:2024-04-11']
# ['02_intermediate.2024-04-11.foo_intermediate_df']
# {2024-04-12}
# ['01_raw.{2024-04-12}.foo_raw_df', 'params:2024-04-12']
# ['02_intermediate.2024-04-12.foo_intermediate_df']
# {2024-04-13}
# ['01_raw.{2024-04-13}.foo_raw_df', 'params:2024-04-13']
# ['02_intermediate.2024-04-13.foo_intermediate_df']
# {2024-04-14}
# ['01_raw.{2024-04-14}.foo_raw_df', 'params:2024-04-14']
# ['02_intermediate.2024-04-14.foo_intermediate_df']
# {2024-04-15}
# ['01_raw.{2024-04-15}.foo_raw_df', 'params:2024-04-15']
# ['02_intermediate.2024-04-15.foo_intermediate_df']
# {2024-04-16}
# ['01_raw.{2024-04-16}.foo_raw_df', 'params:2024-04-16']
# ['02_intermediate.2024-04-16.foo_intermediate_df']
# {2024-04-17}
# ['01_raw.{2024-04-17}.foo_raw_df', 'params:2024-04-17']
# ['02_intermediate.2024-04-17.foo_intermediate_df']
# {2024-04-18}
# ['01_raw.{2024-04-18}.foo_raw_df', 'params:2024-04-18']
# ['02_intermediate.2024-04-18.foo_intermediate_df']
# {2024-04-19}
# ['01_raw.{2024-04-19}.foo_raw_df', 'params:2024-04-19']
# ['02_intermediate.2024-04-19.foo_intermediate_df']
# {2024-04-20}
# ['01_raw.{2024-04-20}.foo_raw_df', 'params:2024-04-20']
# ['02_intermediate.2024-04-20.foo_intermediate_df']
# {2024-04-21}
# ['01_raw.{2024-04-21}.foo_raw_df', 'params:2024-04-21']
# ['02_intermediate.2024-04-21.foo_intermediate_df']
# {2024-04-22}
# ['01_raw.{2024-04-22}.foo_raw_df', 'params:2024-04-22']
# ['02_intermediate.2024-04-22.foo_intermediate_df']
# {2024-04-23}
# ['01_raw.{2024-04-23}.foo_raw_df', 'params:2024-04-23']
# ['02_intermediate.2024-04-23.foo_intermediate_df']
# {2024-04-24}
# ['01_raw.{2024-04-24}.foo_raw_df', 'params:2024-04-24']
# ['02_intermediate.2024-04-24.foo_intermediate_df']
# {2024-04-25}
# ['01_raw.{2024-04-25}.foo_raw_df', 'params:2024-04-25']
# ['02_intermediate.2024-04-25.foo_intermediate_df']
# {2024-04-26}
# ['01_raw.{2024-04-26}.foo_raw_df', 'params:2024-04-26']
# ['02_intermediate.2024-04-26.foo_intermediate_df']
# {2024-04-27}
# ['01_raw.{2024-04-27}.foo_raw_df', 'params:2024-04-27']
# ['02_intermediate.2024-04-27.foo_intermediate_df']
# {2024-04-28}
# ['01_raw.{2024-04-28}.foo_raw_df', 'params:2024-04-28']
# ['02_intermediate.2024-04-28.foo_intermediate_df']
# {2024-04-29}
# ['01_raw.{2024-04-29}.foo_raw_df', 'params:2024-04-29']
# ['02_intermediate.2024-04-29.foo_intermediate_df']
# {2024-04-30}
# ['01_raw.{2024-04-30}.foo_raw_df', 'params:2024-04-30']
# ['02_intermediate.2024-04-30.foo_intermediate_df']
# {2024-05-01}
# ['01_raw.{2024-05-01}.foo_raw_df', 'params:2024-05-01']
# ['02_intermediate.2024-05-01.foo_intermediate_df']
# {2024-05-02}
# ['01_raw.{2024-05-02}.foo_raw_df', 'params:2024-05-02']
# ['02_intermediate.2024-05-02.foo_intermediate_df']
# {2024-05-03}
# ['01_raw.{2024-05-03}.foo_raw_df', 'params:2024-05-03']
# ['02_intermediate.2024-05-03.foo_intermediate_df']
# {2024-05-04}
# ['01_raw.{2024-05-04}.foo_raw_df', 'params:2024-05-04']
# ['02_intermediate.2024-05-04.foo_intermediate_df']
# {2024-05-05}
# ['01_raw.{2024-05-05}.foo_raw_df', 'params:2024-05-05']
# ['02_intermediate.2024-05-05.foo_intermediate_df']
# {2024-05-06}
# ['01_raw.{2024-05-06}.foo_raw_df', 'params:2024-05-06']
# ['02_intermediate.2024-05-06.foo_intermediate_df']
# {2024-05-07}
# ['01_raw.{2024-05-07}.foo_raw_df', 'params:2024-05-07']
# ['02_intermediate.2024-05-07.foo_intermediate_df']
# {2024-05-08}
# ['01_raw.{2024-05-08}.foo_raw_df', 'params:2024-05-08']
# ['02_intermediate.2024-05-08.foo_intermediate_df']
# {2024-05-09}
# ['01_raw.{2024-05-09}.foo_raw_df', 'params:2024-05-09']
# ['02_intermediate.2024-05-09.foo_intermediate_df']
# {2024-05-10}
# ['01_raw.{2024-05-10}.foo_raw_df', 'params:2024-05-10']
# ['02_intermediate.2024-05-10.foo_intermediate_df']
# {2024-05-11}
# ['01_raw.{2024-05-11}.foo_raw_df', 'params:2024-05-11']
# ['02_intermediate.2024-05-11.foo_intermediate_df']
# {2024-05-12}
# ['01_raw.{2024-05-12}.foo_raw_df', 'params:2024-05-12']
# ['02_intermediate.2024-05-12.foo_intermediate_df']
# {2024-05-13}
# ['01_raw.{2024-05-13}.foo_raw_df', 'params:2024-05-13']
# ['02_intermediate.2024-05-13.foo_intermediate_df']
# {2024-05-14}
# ['01_raw.{2024-05-14}.foo_raw_df', 'params:2024-05-14']
# ['02_intermediate.2024-05-14.foo_intermediate_df']
# {2024-05-15}
# ['01_raw.{2024-05-15}.foo_raw_df', 'params:2024-05-15']
# ['02_intermediate.2024-05-15.foo_intermediate_df']
# {2024-05-16}
# ['01_raw.{2024-05-16}.foo_raw_df', 'params:2024-05-16']
# ['02_intermediate.2024-05-16.foo_intermediate_df']
# {2024-05-17}
# ['01_raw.{2024-05-17}.foo_raw_df', 'params:2024-05-17']
# ['02_intermediate.2024-05-17.foo_intermediate_df']
# {2024-05-18}
# ['01_raw.{2024-05-18}.foo_raw_df', 'params:2024-05-18']
# ['02_intermediate.2024-05-18.foo_intermediate_df']
# {2024-05-19}
# ['01_raw.{2024-05-19}.foo_raw_df', 'params:2024-05-19']
# ['02_intermediate.2024-05-19.foo_intermediate_df']
# {2024-05-20}
# ['01_raw.{2024-05-20}.foo_raw_df', 'params:2024-05-20']
# ['02_intermediate.2024-05-20.foo_intermediate_df']
# {2024-05-21}
# ['01_raw.{2024-05-21}.foo_raw_df', 'params:2024-05-21']
# ['02_intermediate.2024-05-21.foo_intermediate_df']
# {2024-05-22}
# ['01_raw.{2024-05-22}.foo_raw_df', 'params:2024-05-22']
# ['02_intermediate.2024-05-22.foo_intermediate_df']
# {2024-05-23}
# ['01_raw.{2024-05-23}.foo_raw_df', 'params:2024-05-23']
# ['02_intermediate.2024-05-23.foo_intermediate_df']
# {2024-05-24}
# ['01_raw.{2024-05-24}.foo_raw_df', 'params:2024-05-24']
# ['02_intermediate.2024-05-24.foo_intermediate_df']
# {2024-05-25}
# ['01_raw.{2024-05-25}.foo_raw_df', 'params:2024-05-25']
# ['02_intermediate.2024-05-25.foo_intermediate_df']
# {2024-05-26}
# ['01_raw.{2024-05-26}.foo_raw_df', 'params:2024-05-26']
# ['02_intermediate.2024-05-26.foo_intermediate_df']
# {2024-05-27}
# ['01_raw.{2024-05-27}.foo_raw_df', 'params:2024-05-27']
# ['02_intermediate.2024-05-27.foo_intermediate_df']
# {2024-05-28}
# ['01_raw.{2024-05-28}.foo_raw_df', 'params:2024-05-28']
# ['02_intermediate.2024-05-28.foo_intermediate_df']
# {2024-05-29}
# ['01_raw.{2024-05-29}.foo_raw_df', 'params:2024-05-29']
# ['02_intermediate.2024-05-29.foo_intermediate_df']
# {2024-05-30}
# ['01_raw.{2024-05-30}.foo_raw_df', 'params:2024-05-30']
# ['02_intermediate.2024-05-30.foo_intermediate_df']
# {2024-05-31}
# ['01_raw.{2024-05-31}.foo_raw_df', 'params:2024-05-31']
# ['02_intermediate.2024-05-31.foo_intermediate_df']
# {2024-06-01}
# ['01_raw.{2024-06-01}.foo_raw_df', 'params:2024-06-01']
# ['02_intermediate.2024-06-01.foo_intermediate_df']
# {2024-06-02}
# ['01_raw.{2024-06-02}.foo_raw_df', 'params:2024-06-02']
# ['02_intermediate.2024-06-02.foo_intermediate_df']
# {2024-06-03}
# ['01_raw.{2024-06-03}.foo_raw_df', 'params:2024-06-03']
# ['02_intermediate.2024-06-03.foo_intermediate_df']
# {2024-06-04}
# ['01_raw.{2024-06-04}.foo_raw_df', 'params:2024-06-04']
# ['02_intermediate.2024-06-04.foo_intermediate_df']
# {2024-06-05}
# ['01_raw.{2024-06-05}.foo_raw_df', 'params:2024-06-05']
# ['02_intermediate.2024-06-05.foo_intermediate_df']
# {2024-06-06}
# ['01_raw.{2024-06-06}.foo_raw_df', 'params:2024-06-06']
# ['02_intermediate.2024-06-06.foo_intermediate_df']
# {2024-06-07}
# ['01_raw.{2024-06-07}.foo_raw_df', 'params:2024-06-07']
# ['02_intermediate.2024-06-07.foo_intermediate_df']
# {2024-06-08}
# ['01_raw.{2024-06-08}.foo_raw_df', 'params:2024-06-08']
# ['02_intermediate.2024-06-08.foo_intermediate_df']
# {2024-06-09}
# ['01_raw.{2024-06-09}.foo_raw_df', 'params:2024-06-09']
# ['02_intermediate.2024-06-09.foo_intermediate_df']
# {2024-06-10}
# ['01_raw.{2024-06-10}.foo_raw_df', 'params:2024-06-10']
# ['02_intermediate.2024-06-10.foo_intermediate_df']
# {2024-06-11}
# ['01_raw.{2024-06-11}.foo_raw_df', 'params:2024-06-11']
# ['02_intermediate.2024-06-11.foo_intermediate_df']
# {2024-06-12}
# ['01_raw.{2024-06-12}.foo_raw_df', 'params:2024-06-12']
# ['02_intermediate.2024-06-12.foo_intermediate_df']
# {2024-06-13}
# ['01_raw.{2024-06-13}.foo_raw_df', 'params:2024-06-13']
# ['02_intermediate.2024-06-13.foo_intermediate_df']
# {2024-06-14}
# ['01_raw.{2024-06-14}.foo_raw_df', 'params:2024-06-14']
# ['02_intermediate.2024-06-14.foo_intermediate_df']
# {2024-06-15}
# ['01_raw.{2024-06-15}.foo_raw_df', 'params:2024-06-15']
# ['02_intermediate.2024-06-15.foo_intermediate_df']
# {2024-06-16}
# ['01_raw.{2024-06-16}.foo_raw_df', 'params:2024-06-16']
# ['02_intermediate.2024-06-16.foo_intermediate_df']
# {2024-06-17}
# ['01_raw.{2024-06-17}.foo_raw_df', 'params:2024-06-17']
# ['02_intermediate.2024-06-17.foo_intermediate_df']
# {2024-06-18}
# ['01_raw.{2024-06-18}.foo_raw_df', 'params:2024-06-18']
# ['02_intermediate.2024-06-18.foo_intermediate_df']
# {2024-06-19}
# ['01_raw.{2024-06-19}.foo_raw_df', 'params:2024-06-19']
# ['02_intermediate.2024-06-19.foo_intermediate_df']
# {2024-06-20}
# ['01_raw.{2024-06-20}.foo_raw_df', 'params:2024-06-20']
# ['02_intermediate.2024-06-20.foo_intermediate_df']
# {2024-06-21}
# ['01_raw.{2024-06-21}.foo_raw_df', 'params:2024-06-21']
# ['02_intermediate.2024-06-21.foo_intermediate_df']
# {2024-06-22}
# ['01_raw.{2024-06-22}.foo_raw_df', 'params:2024-06-22']
# ['02_intermediate.2024-06-22.foo_intermediate_df']
# {2024-06-23}
# ['01_raw.{2024-06-23}.foo_raw_df', 'params:2024-06-23']
# ['02_intermediate.2024-06-23.foo_intermediate_df']
# {2024-06-24}
# ['01_raw.{2024-06-24}.foo_raw_df', 'params:2024-06-24']
# ['02_intermediate.2024-06-24.foo_intermediate_df']
# {2024-06-25}
# ['01_raw.{2024-06-25}.foo_raw_df', 'params:2024-06-25']
# ['02_intermediate.2024-06-25.foo_intermediate_df']
# {2024-06-26}
# ['01_raw.{2024-06-26}.foo_raw_df', 'params:2024-06-26']
# ['02_intermediate.2024-06-26.foo_intermediate_df']
# {2024-06-27}
# ['01_raw.{2024-06-27}.foo_raw_df', 'params:2024-06-27']
# ['02_intermediate.2024-06-27.foo_intermediate_df']
# {2024-06-28}
# ['01_raw.{2024-06-28}.foo_raw_df', 'params:2024-06-28']
# ['02_intermediate.2024-06-28.foo_intermediate_df']
# {2024-06-29}
# ['01_raw.{2024-06-29}.foo_raw_df', 'params:2024-06-29']
# ['02_intermediate.2024-06-29.foo_intermediate_df']
# {2024-06-30}
# ['01_raw.{2024-06-30}.foo_raw_df', 'params:2024-06-30']
# ['02_intermediate.2024-06-30.foo_intermediate_df']
# {2024-07-01}
# ['01_raw.{2024-07-01}.foo_raw_df', 'params:2024-07-01']
# ['02_intermediate.2024-07-01.foo_intermediate_df']
# {2024-07-02}
# ['01_raw.{2024-07-02}.foo_raw_df', 'params:2024-07-02']
# ['02_intermediate.2024-07-02.foo_intermediate_df']
# {2024-07-03}
# ['01_raw.{2024-07-03}.foo_raw_df', 'params:2024-07-03']
# ['02_intermediate.2024-07-03.foo_intermediate_df']
# {2024-07-04}
# ['01_raw.{2024-07-04}.foo_raw_df', 'params:2024-07-04']
# ['02_intermediate.2024-07-04.foo_intermediate_df']
# {2024-07-05}
# ['01_raw.{2024-07-05}.foo_raw_df', 'params:2024-07-05']
# ['02_intermediate.2024-07-05.foo_intermediate_df']
# {2024-07-06}
# ['01_raw.{2024-07-06}.foo_raw_df', 'params:2024-07-06']
# ['02_intermediate.2024-07-06.foo_intermediate_df']
# {2024-07-07}
# ['01_raw.{2024-07-07}.foo_raw_df', 'params:2024-07-07']
# ['02_intermediate.2024-07-07.foo_intermediate_df']
# {2024-07-08}
# ['01_raw.{2024-07-08}.foo_raw_df', 'params:2024-07-08']
# ['02_intermediate.2024-07-08.foo_intermediate_df']
# {2024-07-09}
# ['01_raw.{2024-07-09}.foo_raw_df', 'params:2024-07-09']
# ['02_intermediate.2024-07-09.foo_intermediate_df']
# {2024-07-10}
# ['01_raw.{2024-07-10}.foo_raw_df', 'params:2024-07-10']
# ['02_intermediate.2024-07-10.foo_intermediate_df']
# {2024-07-11}
# ['01_raw.{2024-07-11}.foo_raw_df', 'params:2024-07-11']
# ['02_intermediate.2024-07-11.foo_intermediate_df']
# {2024-07-12}
# ['01_raw.{2024-07-12}.foo_raw_df', 'params:2024-07-12']
# ['02_intermediate.2024-07-12.foo_intermediate_df']
# {2024-07-13}
# ['01_raw.{2024-07-13}.foo_raw_df', 'params:2024-07-13']
# ['02_intermediate.2024-07-13.foo_intermediate_df']
# {2024-07-14}
# ['01_raw.{2024-07-14}.foo_raw_df', 'params:2024-07-14']
# ['02_intermediate.2024-07-14.foo_intermediate_df']
# {2024-07-15}
# ['01_raw.{2024-07-15}.foo_raw_df', 'params:2024-07-15']
# ['02_intermediate.2024-07-15.foo_intermediate_df']
# {2024-07-16}
# ['01_raw.{2024-07-16}.foo_raw_df', 'params:2024-07-16']
# ['02_intermediate.2024-07-16.foo_intermediate_df']
# {2024-07-17}
# ['01_raw.{2024-07-17}.foo_raw_df', 'params:2024-07-17']
# ['02_intermediate.2024-07-17.foo_intermediate_df']
# {2024-07-18}
# ['01_raw.{2024-07-18}.foo_raw_df', 'params:2024-07-18']
# ['02_intermediate.2024-07-18.foo_intermediate_df']
# {2024-07-19}
# ['01_raw.{2024-07-19}.foo_raw_df', 'params:2024-07-19']
# ['02_intermediate.2024-07-19.foo_intermediate_df']
# {2024-07-20}
# ['01_raw.{2024-07-20}.foo_raw_df', 'params:2024-07-20']
# ['02_intermediate.2024-07-20.foo_intermediate_df']
# {2024-07-21}
# ['01_raw.{2024-07-21}.foo_raw_df', 'params:2024-07-21']
# ['02_intermediate.2024-07-21.foo_intermediate_df']
# {2024-07-22}
# ['01_raw.{2024-07-22}.foo_raw_df', 'params:2024-07-22']
# ['02_intermediate.2024-07-22.foo_intermediate_df']
# {2024-07-23}
# ['01_raw.{2024-07-23}.foo_raw_df', 'params:2024-07-23']
# ['02_intermediate.2024-07-23.foo_intermediate_df']
# {2024-07-24}
# ['01_raw.{2024-07-24}.foo_raw_df', 'params:2024-07-24']
# ['02_intermediate.2024-07-24.foo_intermediate_df']
# {2024-07-25}
# ['01_raw.{2024-07-25}.foo_raw_df', 'params:2024-07-25']
# ['02_intermediate.2024-07-25.foo_intermediate_df']
# {2024-07-26}
# ['01_raw.{2024-07-26}.foo_raw_df', 'params:2024-07-26']
# ['02_intermediate.2024-07-26.foo_intermediate_df']
# {2024-07-27}
# ['01_raw.{2024-07-27}.foo_raw_df', 'params:2024-07-27']
# ['02_intermediate.2024-07-27.foo_intermediate_df']
# {2024-07-28}
# ['01_raw.{2024-07-28}.foo_raw_df', 'params:2024-07-28']
# ['02_intermediate.2024-07-28.foo_intermediate_df']
# {2024-07-29}
# ['01_raw.{2024-07-29}.foo_raw_df', 'params:2024-07-29']
# ['02_intermediate.2024-07-29.foo_intermediate_df']
# {2024-07-30}
# ['01_raw.{2024-07-30}.foo_raw_df', 'params:2024-07-30']
# ['02_intermediate.2024-07-30.foo_intermediate_df']
# {2024-07-31}
# ['01_raw.{2024-07-31}.foo_raw_df', 'params:2024-07-31']
# ['02_intermediate.2024-07-31.foo_intermediate_df']
# {2024-08-01}
# ['01_raw.{2024-08-01}.foo_raw_df', 'params:2024-08-01']
# ['02_intermediate.2024-08-01.foo_intermediate_df']
# {2024-08-02}
# ['01_raw.{2024-08-02}.foo_raw_df', 'params:2024-08-02']
# ['02_intermediate.2024-08-02.foo_intermediate_df']
# {2024-08-03}
# ['01_raw.{2024-08-03}.foo_raw_df', 'params:2024-08-03']
# ['02_intermediate.2024-08-03.foo_intermediate_df']
# {2024-08-04}
# ['01_raw.{2024-08-04}.foo_raw_df', 'params:2024-08-04']
# ['02_intermediate.2024-08-04.foo_intermediate_df']
# {2024-08-05}
# ['01_raw.{2024-08-05}.foo_raw_df', 'params:2024-08-05']
# ['02_intermediate.2024-08-05.foo_intermediate_df']
# {2024-08-06}
# ['01_raw.{2024-08-06}.foo_raw_df', 'params:2024-08-06']
# ['02_intermediate.2024-08-06.foo_intermediate_df']
# {2024-08-07}
# ['01_raw.{2024-08-07}.foo_raw_df', 'params:2024-08-07']
# ['02_intermediate.2024-08-07.foo_intermediate_df']
# {2024-08-08}
# ['01_raw.{2024-08-08}.foo_raw_df', 'params:2024-08-08']
# ['02_intermediate.2024-08-08.foo_intermediate_df']
# {2024-08-09}
# ['01_raw.{2024-08-09}.foo_raw_df', 'params:2024-08-09']
# ['02_intermediate.2024-08-09.foo_intermediate_df']
# {2024-08-10}
# ['01_raw.{2024-08-10}.foo_raw_df', 'params:2024-08-10']
# ['02_intermediate.2024-08-10.foo_intermediate_df']
# {2024-08-11}
# ['01_raw.{2024-08-11}.foo_raw_df', 'params:2024-08-11']
# ['02_intermediate.2024-08-11.foo_intermediate_df']
# {2024-08-12}
# ['01_raw.{2024-08-12}.foo_raw_df', 'params:2024-08-12']
# ['02_intermediate.2024-08-12.foo_intermediate_df']
# {2024-08-13}
# ['01_raw.{2024-08-13}.foo_raw_df', 'params:2024-08-13']
# ['02_intermediate.2024-08-13.foo_intermediate_df']
# {2024-08-14}
# ['01_raw.{2024-08-14}.foo_raw_df', 'params:2024-08-14']
# ['02_intermediate.2024-08-14.foo_intermediate_df']
# {2024-08-15}
# ['01_raw.{2024-08-15}.foo_raw_df', 'params:2024-08-15']
# ['02_intermediate.2024-08-15.foo_intermediate_df']
# {2024-08-16}
# ['01_raw.{2024-08-16}.foo_raw_df', 'params:2024-08-16']
# ['02_intermediate.2024-08-16.foo_intermediate_df']
# {2024-08-17}
# ['01_raw.{2024-08-17}.foo_raw_df', 'params:2024-08-17']
# ['02_intermediate.2024-08-17.foo_intermediate_df']
# {2024-08-18}
# ['01_raw.{2024-08-18}.foo_raw_df', 'params:2024-08-18']
# ['02_intermediate.2024-08-18.foo_intermediate_df']
# {2024-08-19}
# ['01_raw.{2024-08-19}.foo_raw_df', 'params:2024-08-19']
# ['02_intermediate.2024-08-19.foo_intermediate_df']
# {2024-08-20}
# ['01_raw.{2024-08-20}.foo_raw_df', 'params:2024-08-20']
# ['02_intermediate.2024-08-20.foo_intermediate_df']
# {2024-08-21}
# ['01_raw.{2024-08-21}.foo_raw_df', 'params:2024-08-21']
# ['02_intermediate.2024-08-21.foo_intermediate_df']
# {2024-08-22}
# ['01_raw.{2024-08-22}.foo_raw_df', 'params:2024-08-22']
# ['02_intermediate.2024-08-22.foo_intermediate_df']
# {2024-08-23}
# ['01_raw.{2024-08-23}.foo_raw_df', 'params:2024-08-23']
# ['02_intermediate.2024-08-23.foo_intermediate_df']
# {2024-08-24}
# ['01_raw.{2024-08-24}.foo_raw_df', 'params:2024-08-24']
# ['02_intermediate.2024-08-24.foo_intermediate_df']
# {2024-08-25}
# ['01_raw.{2024-08-25}.foo_raw_df', 'params:2024-08-25']
# ['02_intermediate.2024-08-25.foo_intermediate_df']
# {2024-08-26}
# ['01_raw.{2024-08-26}.foo_raw_df', 'params:2024-08-26']
# ['02_intermediate.2024-08-26.foo_intermediate_df']
# {2024-08-27}
# ['01_raw.{2024-08-27}.foo_raw_df', 'params:2024-08-27']
# ['02_intermediate.2024-08-27.foo_intermediate_df']
# {2024-08-28}
# ['01_raw.{2024-08-28}.foo_raw_df', 'params:2024-08-28']
# ['02_intermediate.2024-08-28.foo_intermediate_df']
# {2024-08-29}
# ['01_raw.{2024-08-29}.foo_raw_df', 'params:2024-08-29']
# ['02_intermediate.2024-08-29.foo_intermediate_df']
# {2024-08-30}
# ['01_raw.{2024-08-30}.foo_raw_df', 'params:2024-08-30']
# ['02_intermediate.2024-08-30.foo_intermediate_df']
# {2024-08-31}
# ['01_raw.{2024-08-31}.foo_raw_df', 'params:2024-08-31']
# ['02_intermediate.2024-08-31.foo_intermediate_df']
# {2024-09-01}
# ['01_raw.{2024-09-01}.foo_raw_df', 'params:2024-09-01']
# ['02_intermediate.2024-09-01.foo_intermediate_df']
# {2024-09-02}
# ['01_raw.{2024-09-02}.foo_raw_df', 'params:2024-09-02']
# ['02_intermediate.2024-09-02.foo_intermediate_df']
# {2024-09-03}
# ['01_raw.{2024-09-03}.foo_raw_df', 'params:2024-09-03']
# ['02_intermediate.2024-09-03.foo_intermediate_df']
# {2024-09-04}
# ['01_raw.{2024-09-04}.foo_raw_df', 'params:2024-09-04']
# ['02_intermediate.2024-09-04.foo_intermediate_df']
# {2024-09-05}
# ['01_raw.{2024-09-05}.foo_raw_df', 'params:2024-09-05']
# ['02_intermediate.2024-09-05.foo_intermediate_df']
# {2024-09-06}
# ['01_raw.{2024-09-06}.foo_raw_df', 'params:2024-09-06']
# ['02_intermediate.2024-09-06.foo_intermediate_df']
# {2024-09-07}
# ['01_raw.{2024-09-07}.foo_raw_df', 'params:2024-09-07']
# ['02_intermediate.2024-09-07.foo_intermediate_df']
# {2024-09-08}
# ['01_raw.{2024-09-08}.foo_raw_df', 'params:2024-09-08']
# ['02_intermediate.2024-09-08.foo_intermediate_df']
# {2024-09-09}
# ['01_raw.{2024-09-09}.foo_raw_df', 'params:2024-09-09']
# ['02_intermediate.2024-09-09.foo_intermediate_df']
# {2024-09-10}
# ['01_raw.{2024-09-10}.foo_raw_df', 'params:2024-09-10']
# ['02_intermediate.2024-09-10.foo_intermediate_df']
# {2024-09-11}
# ['01_raw.{2024-09-11}.foo_raw_df', 'params:2024-09-11']
# ['02_intermediate.2024-09-11.foo_intermediate_df']
# {2024-09-12}
# ['01_raw.{2024-09-12}.foo_raw_df', 'params:2024-09-12']
# ['02_intermediate.2024-09-12.foo_intermediate_df']
# {2024-09-13}
# ['01_raw.{2024-09-13}.foo_raw_df', 'params:2024-09-13']
# ['02_intermediate.2024-09-13.foo_intermediate_df']
# {2024-09-14}
# ['01_raw.{2024-09-14}.foo_raw_df', 'params:2024-09-14']
# ['02_intermediate.2024-09-14.foo_intermediate_df']
# {2024-09-15}
# ['01_raw.{2024-09-15}.foo_raw_df', 'params:2024-09-15']
# ['02_intermediate.2024-09-15.foo_intermediate_df']
# {2024-09-16}
# ['01_raw.{2024-09-16}.foo_raw_df', 'params:2024-09-16']
# ['02_intermediate.2024-09-16.foo_intermediate_df']
# {2024-09-17}
# ['01_raw.{2024-09-17}.foo_raw_df', 'params:2024-09-17']
# ['02_intermediate.2024-09-17.foo_intermediate_df']
# {2024-09-18}
# ['01_raw.{2024-09-18}.foo_raw_df', 'params:2024-09-18']
# ['02_intermediate.2024-09-18.foo_intermediate_df']
# {2024-09-19}
# ['01_raw.{2024-09-19}.foo_raw_df', 'params:2024-09-19']
# ['02_intermediate.2024-09-19.foo_intermediate_df']
# {2024-09-20}
# ['01_raw.{2024-09-20}.foo_raw_df', 'params:2024-09-20']
# ['02_intermediate.2024-09-20.foo_intermediate_df']
# {2024-09-21}
# ['01_raw.{2024-09-21}.foo_raw_df', 'params:2024-09-21']
# ['02_intermediate.2024-09-21.foo_intermediate_df']
# {2024-09-22}
# ['01_raw.{2024-09-22}.foo_raw_df', 'params:2024-09-22']
# ['02_intermediate.2024-09-22.foo_intermediate_df']
# {2024-09-23}
# ['01_raw.{2024-09-23}.foo_raw_df', 'params:2024-09-23']
# ['02_intermediate.2024-09-23.foo_intermediate_df']
# {2024-09-24}
# ['01_raw.{2024-09-24}.foo_raw_df', 'params:2024-09-24']
# ['02_intermediate.2024-09-24.foo_intermediate_df']
# {2024-09-25}
# ['01_raw.{2024-09-25}.foo_raw_df', 'params:2024-09-25']
# ['02_intermediate.2024-09-25.foo_intermediate_df']
# {2024-09-26}
# ['01_raw.{2024-09-26}.foo_raw_df', 'params:2024-09-26']
# ['02_intermediate.2024-09-26.foo_intermediate_df']
# {2024-09-27}
# ['01_raw.{2024-09-27}.foo_raw_df', 'params:2024-09-27']
# ['02_intermediate.2024-09-27.foo_intermediate_df']
# {2024-09-28}
# ['01_raw.{2024-09-28}.foo_raw_df', 'params:2024-09-28']
# ['02_intermediate.2024-09-28.foo_intermediate_df']
# {2024-09-29}
# ['01_raw.{2024-09-29}.foo_raw_df', 'params:2024-09-29']
# ['02_intermediate.2024-09-29.foo_intermediate_df']
# {2024-09-30}
# ['01_raw.{2024-09-30}.foo_raw_df', 'params:2024-09-30']
# ['02_intermediate.2024-09-30.foo_intermediate_df']
# {2024-10-01}
# ['01_raw.{2024-10-01}.foo_raw_df', 'params:2024-10-01']
# ['02_intermediate.2024-10-01.foo_intermediate_df']
# {2024-10-02}
# ['01_raw.{2024-10-02}.foo_raw_df', 'params:2024-10-02']
# ['02_intermediate.2024-10-02.foo_intermediate_df']
# {2024-10-03}
# ['01_raw.{2024-10-03}.foo_raw_df', 'params:2024-10-03']
# ['02_intermediate.2024-10-03.foo_intermediate_df']
# {2024-10-04}
# ['01_raw.{2024-10-04}.foo_raw_df', 'params:2024-10-04']
# ['02_intermediate.2024-10-04.foo_intermediate_df']
# {2024-10-05}
# ['01_raw.{2024-10-05}.foo_raw_df', 'params:2024-10-05']
# ['02_intermediate.2024-10-05.foo_intermediate_df']
# {2024-10-06}
# ['01_raw.{2024-10-06}.foo_raw_df', 'params:2024-10-06']
# ['02_intermediate.2024-10-06.foo_intermediate_df']
# {2024-10-07}
# ['01_raw.{2024-10-07}.foo_raw_df', 'params:2024-10-07']
# ['02_intermediate.2024-10-07.foo_intermediate_df']
# {2024-10-08}
# ['01_raw.{2024-10-08}.foo_raw_df', 'params:2024-10-08']
# ['02_intermediate.2024-10-08.foo_intermediate_df']
# {2024-10-09}
# ['01_raw.{2024-10-09}.foo_raw_df', 'params:2024-10-09']
# ['02_intermediate.2024-10-09.foo_intermediate_df']
# {2024-10-10}
# ['01_raw.{2024-10-10}.foo_raw_df', 'params:2024-10-10']
# ['02_intermediate.2024-10-10.foo_intermediate_df']
# {2024-10-11}
# ['01_raw.{2024-10-11}.foo_raw_df', 'params:2024-10-11']
# ['02_intermediate.2024-10-11.foo_intermediate_df']
# {2024-10-12}
# ['01_raw.{2024-10-12}.foo_raw_df', 'params:2024-10-12']
# ['02_intermediate.2024-10-12.foo_intermediate_df']
# {2024-10-13}
# ['01_raw.{2024-10-13}.foo_raw_df', 'params:2024-10-13']
# ['02_intermediate.2024-10-13.foo_intermediate_df']
# {2024-10-14}
# ['01_raw.{2024-10-14}.foo_raw_df', 'params:2024-10-14']
# ['02_intermediate.2024-10-14.foo_intermediate_df']
# {2024-10-15}
# ['01_raw.{2024-10-15}.foo_raw_df', 'params:2024-10-15']
# ['02_intermediate.2024-10-15.foo_intermediate_df']
# {2024-10-16}
# ['01_raw.{2024-10-16}.foo_raw_df', 'params:2024-10-16']
# ['02_intermediate.2024-10-16.foo_intermediate_df']
# {2024-10-17}
# ['01_raw.{2024-10-17}.foo_raw_df', 'params:2024-10-17']
# ['02_intermediate.2024-10-17.foo_intermediate_df']
# {2024-10-18}
# ['01_raw.{2024-10-18}.foo_raw_df', 'params:2024-10-18']
# ['02_intermediate.2024-10-18.foo_intermediate_df']
# {2024-10-19}
# ['01_raw.{2024-10-19}.foo_raw_df', 'params:2024-10-19']
# ['02_intermediate.2024-10-19.foo_intermediate_df']
# {2024-10-20}
# ['01_raw.{2024-10-20}.foo_raw_df', 'params:2024-10-20']
# ['02_intermediate.2024-10-20.foo_intermediate_df']
# {2024-10-21}
# ['01_raw.{2024-10-21}.foo_raw_df', 'params:2024-10-21']
# ['02_intermediate.2024-10-21.foo_intermediate_df']
# {2024-10-22}
# ['01_raw.{2024-10-22}.foo_raw_df', 'params:2024-10-22']
# ['02_intermediate.2024-10-22.foo_intermediate_df']
# {2024-10-23}
# ['01_raw.{2024-10-23}.foo_raw_df', 'params:2024-10-23']
# ['02_intermediate.2024-10-23.foo_intermediate_df']
# {2024-10-24}
# ['01_raw.{2024-10-24}.foo_raw_df', 'params:2024-10-24']
# ['02_intermediate.2024-10-24.foo_intermediate_df']
# {2024-10-25}
# ['01_raw.{2024-10-25}.foo_raw_df', 'params:2024-10-25']
# ['02_intermediate.2024-10-25.foo_intermediate_df']
# {2024-10-26}
# ['01_raw.{2024-10-26}.foo_raw_df', 'params:2024-10-26']
# ['02_intermediate.2024-10-26.foo_intermediate_df']
# {2024-10-27}
# ['01_raw.{2024-10-27}.foo_raw_df', 'params:2024-10-27']
# ['02_intermediate.2024-10-27.foo_intermediate_df']
# {2024-10-28}
# ['01_raw.{2024-10-28}.foo_raw_df', 'params:2024-10-28']
# ['02_intermediate.2024-10-28.foo_intermediate_df']
# {2024-10-29}
# ['01_raw.{2024-10-29}.foo_raw_df', 'params:2024-10-29']
# ['02_intermediate.2024-10-29.foo_intermediate_df']
# {2024-10-30}
# ['01_raw.{2024-10-30}.foo_raw_df', 'params:2024-10-30']
# ['02_intermediate.2024-10-30.foo_intermediate_df']
# {2024-10-31}
# ['01_raw.{2024-10-31}.foo_raw_df', 'params:2024-10-31']
# ['02_intermediate.2024-10-31.foo_intermediate_df']
# {2024-11-01}
# ['01_raw.{2024-11-01}.foo_raw_df', 'params:2024-11-01']
# ['02_intermediate.2024-11-01.foo_intermediate_df']
# {2024-11-02}
# ['01_raw.{2024-11-02}.foo_raw_df', 'params:2024-11-02']
# ['02_intermediate.2024-11-02.foo_intermediate_df']
# {2024-11-03}
# ['01_raw.{2024-11-03}.foo_raw_df', 'params:2024-11-03']
# ['02_intermediate.2024-11-03.foo_intermediate_df']
# {2024-11-04}
# ['01_raw.{2024-11-04}.foo_raw_df', 'params:2024-11-04']
# ['02_intermediate.2024-11-04.foo_intermediate_df']
# {2024-11-05}
# ['01_raw.{2024-11-05}.foo_raw_df', 'params:2024-11-05']
# ['02_intermediate.2024-11-05.foo_intermediate_df']
# {2024-11-06}
# ['01_raw.{2024-11-06}.foo_raw_df', 'params:2024-11-06']
# ['02_intermediate.2024-11-06.foo_intermediate_df']
# {2024-11-07}
# ['01_raw.{2024-11-07}.foo_raw_df', 'params:2024-11-07']
# ['02_intermediate.2024-11-07.foo_intermediate_df']
# {2024-11-08}
# ['01_raw.{2024-11-08}.foo_raw_df', 'params:2024-11-08']
# ['02_intermediate.2024-11-08.foo_intermediate_df']
# {2024-11-09}
# ['01_raw.{2024-11-09}.foo_raw_df', 'params:2024-11-09']
# ['02_intermediate.2024-11-09.foo_intermediate_df']
# {2024-11-10}
# ['01_raw.{2024-11-10}.foo_raw_df', 'params:2024-11-10']
# ['02_intermediate.2024-11-10.foo_intermediate_df']
# {2024-11-11}
# ['01_raw.{2024-11-11}.foo_raw_df', 'params:2024-11-11']
# ['02_intermediate.2024-11-11.foo_intermediate_df']
# {2024-11-12}
# ['01_raw.{2024-11-12}.foo_raw_df', 'params:2024-11-12']
# ['02_intermediate.2024-11-12.foo_intermediate_df']
# {2024-11-13}
# ['01_raw.{2024-11-13}.foo_raw_df', 'params:2024-11-13']
# ['02_intermediate.2024-11-13.foo_intermediate_df']
# {2024-11-14}
# ['01_raw.{2024-11-14}.foo_raw_df', 'params:2024-11-14']
# ['02_intermediate.2024-11-14.foo_intermediate_df']
# {2024-11-15}
# ['01_raw.{2024-11-15}.foo_raw_df', 'params:2024-11-15']
# ['02_intermediate.2024-11-15.foo_intermediate_df']
# {2024-11-16}
# ['01_raw.{2024-11-16}.foo_raw_df', 'params:2024-11-16']
# ['02_intermediate.2024-11-16.foo_intermediate_df']
# {2024-11-17}
# ['01_raw.{2024-11-17}.foo_raw_df', 'params:2024-11-17']
# ['02_intermediate.2024-11-17.foo_intermediate_df']
# {2024-11-18}
# ['01_raw.{2024-11-18}.foo_raw_df', 'params:2024-11-18']
# ['02_intermediate.2024-11-18.foo_intermediate_df']
# {2024-11-19}
# ['01_raw.{2024-11-19}.foo_raw_df', 'params:2024-11-19']
# ['02_intermediate.2024-11-19.foo_intermediate_df']
# {2024-11-20}
# ['01_raw.{2024-11-20}.foo_raw_df', 'params:2024-11-20']
# ['02_intermediate.2024-11-20.foo_intermediate_df']
# {2024-11-21}
# ['01_raw.{2024-11-21}.foo_raw_df', 'params:2024-11-21']
# ['02_intermediate.2024-11-21.foo_intermediate_df']
# {2024-11-22}
# ['01_raw.{2024-11-22}.foo_raw_df', 'params:2024-11-22']
# ['02_intermediate.2024-11-22.foo_intermediate_df']
# {2024-11-23}
# ['01_raw.{2024-11-23}.foo_raw_df', 'params:2024-11-23']
# ['02_intermediate.2024-11-23.foo_intermediate_df']
# {2024-11-24}
# ['01_raw.{2024-11-24}.foo_raw_df', 'params:2024-11-24']
# ['02_intermediate.2024-11-24.foo_intermediate_df']
# {2024-11-25}
# ['01_raw.{2024-11-25}.foo_raw_df', 'params:2024-11-25']
# ['02_intermediate.2024-11-25.foo_intermediate_df']
# {2024-11-26}
# ['01_raw.{2024-11-26}.foo_raw_df', 'params:2024-11-26']
# ['02_intermediate.2024-11-26.foo_intermediate_df']
# {2024-11-27}
# ['01_raw.{2024-11-27}.foo_raw_df', 'params:2024-11-27']
# ['02_intermediate.2024-11-27.foo_intermediate_df']
# {2024-11-28}
# ['01_raw.{2024-11-28}.foo_raw_df', 'params:2024-11-28']
# ['02_intermediate.2024-11-28.foo_intermediate_df']
# {2024-11-29}
# ['01_raw.{2024-11-29}.foo_raw_df', 'params:2024-11-29']
# ['02_intermediate.2024-11-29.foo_intermediate_df']
# {2024-11-30}
# ['01_raw.{2024-11-30}.foo_raw_df', 'params:2024-11-30']
# ['02_intermediate.2024-11-30.foo_intermediate_df']
# {2024-12-01}
# ['01_raw.{2024-12-01}.foo_raw_df', 'params:2024-12-01']
# ['02_intermediate.2024-12-01.foo_intermediate_df']
# {2024-12-02}
# ['01_raw.{2024-12-02}.foo_raw_df', 'params:2024-12-02']
# ['02_intermediate.2024-12-02.foo_intermediate_df']
# {2024-12-03}
# ['01_raw.{2024-12-03}.foo_raw_df', 'params:2024-12-03']
# ['02_intermediate.2024-12-03.foo_intermediate_df']
# {2024-12-04}
# ['01_raw.{2024-12-04}.foo_raw_df', 'params:2024-12-04']
# ['02_intermediate.2024-12-04.foo_intermediate_df']
# {2024-12-05}
# ['01_raw.{2024-12-05}.foo_raw_df', 'params:2024-12-05']
# ['02_intermediate.2024-12-05.foo_intermediate_df']
# {2024-12-06}
# ['01_raw.{2024-12-06}.foo_raw_df', 'params:2024-12-06']
# ['02_intermediate.2024-12-06.foo_intermediate_df']
# {2024-12-07}
# ['01_raw.{2024-12-07}.foo_raw_df', 'params:2024-12-07']
# ['02_intermediate.2024-12-07.foo_intermediate_df']
# {2024-12-08}
# ['01_raw.{2024-12-08}.foo_raw_df', 'params:2024-12-08']
# ['02_intermediate.2024-12-08.foo_intermediate_df']
# {2024-12-09}
# ['01_raw.{2024-12-09}.foo_raw_df', 'params:2024-12-09']
# ['02_intermediate.2024-12-09.foo_intermediate_df']
# {2024-12-10}
# ['01_raw.{2024-12-10}.foo_raw_df', 'params:2024-12-10']
# ['02_intermediate.2024-12-10.foo_intermediate_df']
# {2024-12-11}
# ['01_raw.{2024-12-11}.foo_raw_df', 'params:2024-12-11']
# ['02_intermediate.2024-12-11.foo_intermediate_df']
# {2024-12-12}
# ['01_raw.{2024-12-12}.foo_raw_df', 'params:2024-12-12']
# ['02_intermediate.2024-12-12.foo_intermediate_df']
# {2024-12-13}
# ['01_raw.{2024-12-13}.foo_raw_df', 'params:2024-12-13']
# ['02_intermediate.2024-12-13.foo_intermediate_df']
# {2024-12-14}
# ['01_raw.{2024-12-14}.foo_raw_df', 'params:2024-12-14']
# ['02_intermediate.2024-12-14.foo_intermediate_df']
# {2024-12-15}
# ['01_raw.{2024-12-15}.foo_raw_df', 'params:2024-12-15']
# ['02_intermediate.2024-12-15.foo_intermediate_df']
# {2024-12-16}
# ['01_raw.{2024-12-16}.foo_raw_df', 'params:2024-12-16']
# ['02_intermediate.2024-12-16.foo_intermediate_df']
# {2024-12-17}
# ['01_raw.{2024-12-17}.foo_raw_df', 'params:2024-12-17']
# ['02_intermediate.2024-12-17.foo_intermediate_df']
# {2024-12-18}
# ['01_raw.{2024-12-18}.foo_raw_df', 'params:2024-12-18']
# ['02_intermediate.2024-12-18.foo_intermediate_df']
# {2024-12-19}
# ['01_raw.{2024-12-19}.foo_raw_df', 'params:2024-12-19']
# ['02_intermediate.2024-12-19.foo_intermediate_df']
# {2024-12-20}
# ['01_raw.{2024-12-20}.foo_raw_df', 'params:2024-12-20']
# ['02_intermediate.2024-12-20.foo_intermediate_df']
# {2024-12-21}
# ['01_raw.{2024-12-21}.foo_raw_df', 'params:2024-12-21']
# ['02_intermediate.2024-12-21.foo_intermediate_df']
# {2024-12-22}
# ['01_raw.{2024-12-22}.foo_raw_df', 'params:2024-12-22']
# ['02_intermediate.2024-12-22.foo_intermediate_df']
# {2024-12-23}
# ['01_raw.{2024-12-23}.foo_raw_df', 'params:2024-12-23']
# ['02_intermediate.2024-12-23.foo_intermediate_df']
# {2024-12-24}
# ['01_raw.{2024-12-24}.foo_raw_df', 'params:2024-12-24']
# ['02_intermediate.2024-12-24.foo_intermediate_df']
# {2024-12-25}
# ['01_raw.{2024-12-25}.foo_raw_df', 'params:2024-12-25']
# ['02_intermediate.2024-12-25.foo_intermediate_df']
# {2024-12-26}
# ['01_raw.{2024-12-26}.foo_raw_df', 'params:2024-12-26']
# ['02_intermediate.2024-12-26.foo_intermediate_df']
# {2024-12-27}
# ['01_raw.{2024-12-27}.foo_raw_df', 'params:2024-12-27']
# ['02_intermediate.2024-12-27.foo_intermediate_df']
# {2024-12-28}
# ['01_raw.{2024-12-28}.foo_raw_df', 'params:2024-12-28']
# ['02_intermediate.2024-12-28.foo_intermediate_df']
# {2024-12-29}
# ['01_raw.{2024-12-29}.foo_raw_df', 'params:2024-12-29']
# ['02_intermediate.2024-12-29.foo_intermediate_df']
# {2024-12-30}
# ['01_raw.{2024-12-30}.foo_raw_df', 'params:2024-12-30']
# ['02_intermediate.2024-12-30.foo_intermediate_df']
# {2024-12-31}
# ['01_raw.{2024-12-31}.foo_raw_df', 'params:2024-12-31']
# ['02_intermediate.2024-12-31.foo_intermediate_df']
# {2025-01-01}
# ['01_raw.{2025-01-01}.foo_raw_df', 'params:2025-01-01']
# ['02_intermediate.2025-01-01.foo_intermediate_df']
# {2025-01-02}
# ['01_raw.{2025-01-02}.foo_raw_df', 'params:2025-01-02']
# ['02_intermediate.2025-01-02.foo_intermediate_df']
# {2025-01-03}
# ['01_raw.{2025-01-03}.foo_raw_df', 'params:2025-01-03']
# ['02_intermediate.2025-01-03.foo_intermediate_df']
# {2025-01-04}
# ['01_raw.{2025-01-04}.foo_raw_df', 'params:2025-01-04']
# ['02_intermediate.2025-01-04.foo_intermediate_df']
# {2025-01-05}
# ['01_raw.{2025-01-05}.foo_raw_df', 'params:2025-01-05']
# ['02_intermediate.2025-01-05.foo_intermediate_df']
# {2025-01-06}
# ['01_raw.{2025-01-06}.foo_raw_df', 'params:2025-01-06']
# ['02_intermediate.2025-01-06.foo_intermediate_df']
# {2025-01-07}
# ['01_raw.{2025-01-07}.foo_raw_df', 'params:2025-01-07']
# ['02_intermediate.2025-01-07.foo_intermediate_df']
# {2025-01-08}
# ['01_raw.{2025-01-08}.foo_raw_df', 'params:2025-01-08']
# ['02_intermediate.2025-01-08.foo_intermediate_df']
# {2025-01-09}
# ['01_raw.{2025-01-09}.foo_raw_df', 'params:2025-01-09']
# ['02_intermediate.2025-01-09.foo_intermediate_df']
# {2025-01-10}
# ['01_raw.{2025-01-10}.foo_raw_df', 'params:2025-01-10']
# ['02_intermediate.2025-01-10.foo_intermediate_df']
# {2025-01-11}
# ['01_raw.{2025-01-11}.foo_raw_df', 'params:2025-01-11']
# ['02_intermediate.2025-01-11.foo_intermediate_df']
# {2025-01-12}
# ['01_raw.{2025-01-12}.foo_raw_df', 'params:2025-01-12']
# ['02_intermediate.2025-01-12.foo_intermediate_df']
# {2025-01-13}
# ['01_raw.{2025-01-13}.foo_raw_df', 'params:2025-01-13']
# ['02_intermediate.2025-01-13.foo_intermediate_df']
# {2025-01-14}
# ['01_raw.{2025-01-14}.foo_raw_df', 'params:2025-01-14']
# ['02_intermediate.2025-01-14.foo_intermediate_df']
# {2025-01-15}
# ['01_raw.{2025-01-15}.foo_raw_df', 'params:2025-01-15']
# ['02_intermediate.2025-01-15.foo_intermediate_df']
# {2025-01-16}
# ['01_raw.{2025-01-16}.foo_raw_df', 'params:2025-01-16']
# ['02_intermediate.2025-01-16.foo_intermediate_df']
# {2025-01-17}
# ['01_raw.{2025-01-17}.foo_raw_df', 'params:2025-01-17']
# ['02_intermediate.2025-01-17.foo_intermediate_df']
# {2025-01-18}
# ['01_raw.{2025-01-18}.foo_raw_df', 'params:2025-01-18']
# ['02_intermediate.2025-01-18.foo_intermediate_df']
# {2025-01-19}
# ['01_raw.{2025-01-19}.foo_raw_df', 'params:2025-01-19']
# ['02_intermediate.2025-01-19.foo_intermediate_df']
# {2025-01-20}
# ['01_raw.{2025-01-20}.foo_raw_df', 'params:2025-01-20']
# ['02_intermediate.2025-01-20.foo_intermediate_df']
# {2025-01-21}
# ['01_raw.{2025-01-21}.foo_raw_df', 'params:2025-01-21']
# ['02_intermediate.2025-01-21.foo_intermediate_df']
# {2025-01-22}
# ['01_raw.{2025-01-22}.foo_raw_df', 'params:2025-01-22']
# ['02_intermediate.2025-01-22.foo_intermediate_df']
# {2025-01-23}
# ['01_raw.{2025-01-23}.foo_raw_df', 'params:2025-01-23']
# ['02_intermediate.2025-01-23.foo_intermediate_df']
# {2025-01-24}
# ['01_raw.{2025-01-24}.foo_raw_df', 'params:2025-01-24']
# ['02_intermediate.2025-01-24.foo_intermediate_df']
# {2025-01-25}
# ['01_raw.{2025-01-25}.foo_raw_df', 'params:2025-01-25']
# ['02_intermediate.2025-01-25.foo_intermediate_df']
# {2025-01-26}
# ['01_raw.{2025-01-26}.foo_raw_df', 'params:2025-01-26']
# ['02_intermediate.2025-01-26.foo_intermediate_df']
# {2025-01-27}
# ['01_raw.{2025-01-27}.foo_raw_df', 'params:2025-01-27']
# ['02_intermediate.2025-01-27.foo_intermediate_df']
# {2025-01-28}
# ['01_raw.{2025-01-28}.foo_raw_df', 'params:2025-01-28']
# ['02_intermediate.2025-01-28.foo_intermediate_df']
# {2025-01-29}
# ['01_raw.{2025-01-29}.foo_raw_df', 'params:2025-01-29']
# ['02_intermediate.2025-01-29.foo_intermediate_df']
# {2025-01-30}
# ['01_raw.{2025-01-30}.foo_raw_df', 'params:2025-01-30']
# ['02_intermediate.2025-01-30.foo_intermediate_df']
# {2025-01-31}
# ['01_raw.{2025-01-31}.foo_raw_df', 'params:2025-01-31']
# ['02_intermediate.2025-01-31.foo_intermediate_df']
# {2025-02-01}
# ['01_raw.{2025-02-01}.foo_raw_df', 'params:2025-02-01']
# ['02_intermediate.2025-02-01.foo_intermediate_df']
# {2025-02-02}
# ['01_raw.{2025-02-02}.foo_raw_df', 'params:2025-02-02']
# ['02_intermediate.2025-02-02.foo_intermediate_df']
# {2025-02-03}
# ['01_raw.{2025-02-03}.foo_raw_df', 'params:2025-02-03']
# ['02_intermediate.2025-02-03.foo_intermediate_df']
# {2025-02-04}
# ['01_raw.{2025-02-04}.foo_raw_df', 'params:2025-02-04']
# ['02_intermediate.2025-02-04.foo_intermediate_df']
# {2025-02-05}
# ['01_raw.{2025-02-05}.foo_raw_df', 'params:2025-02-05']
# ['02_intermediate.2025-02-05.foo_intermediate_df']
# {2025-02-06}
# ['01_raw.{2025-02-06}.foo_raw_df', 'params:2025-02-06']
# ['02_intermediate.2025-02-06.foo_intermediate_df']
# {2025-02-07}
# ['01_raw.{2025-02-07}.foo_raw_df', 'params:2025-02-07']
# ['02_intermediate.2025-02-07.foo_intermediate_df']
# {2025-02-08}
# ['01_raw.{2025-02-08}.foo_raw_df', 'params:2025-02-08']
# ['02_intermediate.2025-02-08.foo_intermediate_df']
# {2025-02-09}
# ['01_raw.{2025-02-09}.foo_raw_df', 'params:2025-02-09']
# ['02_intermediate.2025-02-09.foo_intermediate_df']
# {2025-02-10}
# ['01_raw.{2025-02-10}.foo_raw_df', 'params:2025-02-10']
# ['02_intermediate.2025-02-10.foo_intermediate_df']
# {2025-02-11}
# ['01_raw.{2025-02-11}.foo_raw_df', 'params:2025-02-11']
# ['02_intermediate.2025-02-11.foo_intermediate_df']
# {2025-02-12}
# ['01_raw.{2025-02-12}.foo_raw_df', 'params:2025-02-12']
# ['02_intermediate.2025-02-12.foo_intermediate_df']
# {2025-02-13}
# ['01_raw.{2025-02-13}.foo_raw_df', 'params:2025-02-13']
# ['02_intermediate.2025-02-13.foo_intermediate_df']
# {2025-02-14}
# ['01_raw.{2025-02-14}.foo_raw_df', 'params:2025-02-14']
# ['02_intermediate.2025-02-14.foo_intermediate_df']
# {2025-02-15}
# ['01_raw.{2025-02-15}.foo_raw_df', 'params:2025-02-15']
# ['02_intermediate.2025-02-15.foo_intermediate_df']
# {2025-02-16}
# ['01_raw.{2025-02-16}.foo_raw_df', 'params:2025-02-16']
# ['02_intermediate.2025-02-16.foo_intermediate_df']
# {2025-02-17}
# ['01_raw.{2025-02-17}.foo_raw_df', 'params:2025-02-17']
# ['02_intermediate.2025-02-17.foo_intermediate_df']
# {2025-02-18}
# ['01_raw.{2025-02-18}.foo_raw_df', 'params:2025-02-18']
# ['02_intermediate.2025-02-18.foo_intermediate_df']
# {2025-02-19}
# ['01_raw.{2025-02-19}.foo_raw_df', 'params:2025-02-19']
# ['02_intermediate.2025-02-19.foo_intermediate_df']
# {2025-02-20}
# ['01_raw.{2025-02-20}.foo_raw_df', 'params:2025-02-20']
# ['02_intermediate.2025-02-20.foo_intermediate_df']
# {2025-02-21}
# ['01_raw.{2025-02-21}.foo_raw_df', 'params:2025-02-21']
# ['02_intermediate.2025-02-21.foo_intermediate_df']
# {2025-02-22}
# ['01_raw.{2025-02-22}.foo_raw_df', 'params:2025-02-22']
# ['02_intermediate.2025-02-22.foo_intermediate_df']
# {2025-02-23}
# ['01_raw.{2025-02-23}.foo_raw_df', 'params:2025-02-23']
# ['02_intermediate.2025-02-23.foo_intermediate_df']
# {2025-02-24}
# ['01_raw.{2025-02-24}.foo_raw_df', 'params:2025-02-24']
# ['02_intermediate.2025-02-24.foo_intermediate_df']
# {2025-02-25}
# ['01_raw.{2025-02-25}.foo_raw_df', 'params:2025-02-25']
# ['02_intermediate.2025-02-25.foo_intermediate_df']
# {2025-02-26}
# ['01_raw.{2025-02-26}.foo_raw_df', 'params:2025-02-26']
# ['02_intermediate.2025-02-26.foo_intermediate_df']
# {2025-02-27}
# ['01_raw.{2025-02-27}.foo_raw_df', 'params:2025-02-27']
# ['02_intermediate.2025-02-27.foo_intermediate_df']
# {2025-02-28}
# ['01_raw.{2025-02-28}.foo_raw_df', 'params:2025-02-28']
# ['02_intermediate.2025-02-28.foo_intermediate_df']

# %%
inputs = [
    "data_{0}.csv",
    "summary.txt",
    "logs/{0}/log.txt"
]
pattern = "2024-05"

# %%
[x.format(pattern) if "{" in x else x for x in inputs]
# Out:
# ['data_2024-05.csv', 'summary.txt', 'logs/2024-05/log.txt']

# %%
from omegaconf import OmegaConf

params = OmegaConf.load("./conf/base/globals.yml")

# %%
print(params)
# Out:
# {'START_DATE': '2025-01-01', 'END_DATE': '2025-01-02', 'PROCESSING_DATE': '2025-01-01'}

# %%
from datetime import datetime, timedelta

def get_date_range(processing_date: str, range_date: int) -> list[str]:
    # Chuyển đổi chuỗi ngày thành đối tượng datetime
    end_date = datetime.strptime(processing_date, '%Y-%m-%d')
    
    # Tính ngày bắt đầu
    start_date = end_date - timedelta(days=range_date - 1)
    
    # Tạo danh sách các ngày từ start_date đến end_date
    date_list = [
        (start_date + timedelta(days=i)).strftime('%Y-%m-%d') 
        for i in range(range_date)
    ]
    
    return date_list

# %%
date_list = get_date_range('2025-04-30', 40)

# %%
print(type(date_list[0]))
# Out:
# <class 'str'>

# %%
from urllib.parse import urlparse
import os


parsed = urlparse('s3a://curated/reviews')
table_name = os.path.basename(parsed.path.rstrip('/'))

# %%
parsed.scheme
# Out:
# 's3a'

# %%
parsed.path.lstrip('/')
# Out:
# 'reviews'

# %%
table_name
# Out:
# 'reviews'
